# %% [markdown]
# <a href="https://colab.research.google.com/github/aneesh1818/b3_PDS_1120/blob/main/LAB_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Create a sample correlation matrix
data = np.random.rand(6, 6)
corr = pd.DataFrame(data, columns=list("ABCDEF")).corr()

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Heatmap Example - Correlation Matrix")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load example dataset
df = sns.load_dataset("iris")

# Pairplot with color by species
sns.pairplot(df, hue="species", diag_kind="kde", palette="Set2")
plt.suptitle("Pair Plot Example - Iris Dataset", y=1.02)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load example dataset
tips = sns.load_dataset("tips")

# Barplot
plt.figure(figsize=(6, 4))
sns.barplot(x="day", y="total_bill", data=tips, palette="muted")
plt.title("Barplot Example")
plt.show()

# Boxplot
plt.figure(figsize=(6, 4))
sns.boxplot(x="day", y="total_bill", data=tips, palette="Set2")
plt.title("Boxplot Example")
plt.show()

# Violinplot
plt.figure(figsize=(6, 4))
sns.violinplot(x="day", y="total_bill", data=tips, palette="Set3")
plt.title("Violinplot Example")
plt.show()

# Countplot
plt.figure(figsize=(6, 4))
sns.countplot(x="day", data=tips, palette="coolwarm")
plt.title("Countplot Example")
plt.show()
# Out:
# /tmp/ipython-input-1540932530.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="day", y="total_bill", data=tips, palette="muted")
# /tmp/ipython-input-1540932530.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="day", y="total_bill", data=tips, palette="Set2")
# /tmp/ipython-input-1540932530.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="day", y="total_bill", data=tips, palette="Set3")
# /tmp/ipython-input-1540932530.py:27: FutureWarning:
#
# ...
